# %% [markdown]
# ***Tabla***

# %%
mult = 2
for i in range(1, 10):
    print(f"\nTabla de multiplicar del {i}:")
    for j in range(1, 11):
        print(f"Iteración número: {i} x {j} = {i * j}")
# Out:
# Tabla de multiplicar del 1:
# Iteración número: 1 x 1 = 1
# Iteración número: 1 x 2 = 2
# Iteración número: 1 x 3 = 3
# Iteración número: 1 x 4 = 4
# Iteración número: 1 x 5 = 5
# Iteración número: 1 x 6 = 6
# Iteración número: 1 x 7 = 7
# Iteración número: 1 x 8 = 8
# Iteración número: 1 x 9 = 9
# Iteración número: 1 x 10 = 10
#
# Tabla de multiplicar del 2:
# Iteración número: 2 x 1 = 2
# Iteración número: 2 x 2 = 4
# Iteración número: 2 x 3 = 6
# Iteración número: 2 x 4 = 8
# Iteración número: 2 x 5 = 10
# Iteración número: 2 x 6 = 12
# Iteración número: 2 x 7 = 14
# Iteración número: 2 x 8 = 16
# Iteración número: 2 x 9 = 18
# Iteración número: 2 x 10 = 20
#
# Tabla de multiplicar del 3:
# Iteración número: 3 x 1 = 3
# Iteración número: 3 x 2 = 6
# Iteración número: 3 x 3 = 9
# Iteración número: 3 x 4 = 12
# Iteración número: 3 x 5 = 15
# Iteración número: 3 x 6 = 18
# Iteración número: 3 x 7 = 21
# Iteración número: 3 x 8 = 24
# Iteración número: 3 x 9 = 27
# ...
