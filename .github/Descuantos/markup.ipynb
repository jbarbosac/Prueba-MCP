# %% [markdown]
# # 📊 Calculadora de Markup y Descuentos
#
# ## 🔢 Cálculo de Markup: (100/equivalente)-1
#
# Este notebook permite calcular el markup necesario para aplicar el impuesto.

# %%
# ===================================
# 1️⃣ CONFIGURACIÓN DE DESCUENTO
# ===================================
valor_equivalente = 75   # Agregar el valor equivalente del descuento aplicado (%)
# ===================================
# 2️⃣ CONFIGURACIÓN DEL PRODUCTO
# ===================================
requiredPoints =  200569     # Puntos/Millas requeridos
pointValue = 0.01             # Valor de cada punto en USD

# %%
#valor_equivalente = int(input("Ingresa el valor equivalente Ejemplo 70 para 30% "))
#requiredPoints = float(input("Ingresa los puntos requeridos de la reserva"))
#pointValue = float(input("Ingresa el valor del punto en USD Ejemplo 0.01 "))
# Cálculo del markup necesario
markup = (100 / valor_equivalente) - 1

# Mostrar resultados
print("=" * 60)
print("        🎯 RESULTADO DEL CÁLCULO DE MARKUP")
print("=" * 60)
print(f"\n📌 Valor equivalente:       {valor_equivalente}%")
print(f"📈 Markup para el Admin:    {markup:.4f} ({markup * 100:.2f}%)")
print(f"💰 Markup aplicado:         {100 - valor_equivalente}%")
print("\n" + "=" * 60)
# Out:
# ...
#         🎯 RESULTADO DEL CÁLCULO DE MARKUP
# ...
#
# 📌 Valor equivalente:       75%
# 📈 Markup para el Admin:    0.3333 (33.33%)
# 💰 Markup aplicado:         25%
#
# ...

# %% [markdown]
# ---
#
# ## 💳 Cálculo Aplicado al Producto (Millas/Puntos)
#
# Aquí calculamos el valor real del producto con y sin markup aplicado.

# %%
# ===================================
# 📊 CÁLCULOS
# ===================================
# Valor con markup (precio inflado)
valor_usd_con_markup = requiredPoints * pointValue

# Valor sin markup (precio real después del descuento)
valor_markup_aplicado_USD = valor_usd_con_markup * ((100 - valor_equivalente) / 100)

# Diferencia (markup aplicado)
valor_usd_sin_markup = valor_usd_con_markup - valor_markup_aplicado_USD

# ===================================
# 📄 REPORTE DE RESULTADOS
# ===================================
print("\n" + "=" * 60)
print("        💰 ANÁLISIS DE PRECIOS")
print("=" * 60)
print(f"\n🔸 Puntos requeridos:          {requiredPoints:,}")
print(f"🔸 Valor por punto:            USD ${pointValue}")
print(f"🔸 Markup aplicado:            {100 - valor_equivalente}%")
print("\n" + "-" * 60)
print(f"\n📈 Precio Con markup:-------------->USD ${valor_usd_con_markup:}")
print(f"💵 Valor markup:------------------->USD ${valor_markup_aplicado_USD:}")
print(f"📈 Precio sin Markup aplicado:----->USD ${valor_usd_sin_markup:}")

print("\n" + "=" * 60)
# Out:
# ...
#         💰 ANÁLISIS DE PRECIOS
# ...
#
# 🔸 Puntos requeridos:          200,569
# 🔸 Valor por punto:            USD $0.01
# 🔸 Markup aplicado:            25%
#
# ------------------------------------------------------------
#
# 📈 Precio Con markup:-------------->USD $2005.69
# 💵 Valor markup:------------------->USD $501.4225
# 📈 Precio sin Markup aplicado:----->USD $1504.2675
#
# ...
